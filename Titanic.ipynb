# %%
import pandas as pd
df=pd.read_csv("tested.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.loc[:,['PassengerId','Age',]]
# Out:
#      PassengerId   Age
# 0            892  34.5
# 1            893  47.0
# 2            894  62.0
# 3            895  27.0
# 4            896  22.0
# ..           ...   ...
# 413         1305   NaN
# 414         1306  39.0
# 415         1307  38.5
# 416         1308   NaN
# 417         1309   NaN
#
# [418 rows x 2 columns]

# %%
df[df['Age']<20]
# Out:
#      PassengerId  Survived  Pclass  \
# 5            897         0       3
# 8            900         1       3
# 21           913         0       3
# 35           927         0       3
# 55           947         0       3
# ..           ...       ...     ...
# 389         1281         0       3
# 392         1284         0       3
# 395         1287         1       1
# 403         1295         0       1
# 409         1301         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 5                          Svensson, Mr. Johan Cervin    male  14.0      0
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 21                          Olsen, Master. Artur Karl    male   9.0      0
# 35   Katavelas, Mr. Vassilios (Catavelas Vassilios")"    male  18.5      0
# 55                               Rice, Master. Albert    male  10.0      4
# ..                                                ...     ...   ...    ...
# ...

# %%
df[df['Age']>55].shape
# Out:
# (19, 12)

# %%
df[df['Fare']>500]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 343      1  PC 17755  512.3292  B51 B53 B55        C

# %%
df[df['Fare']>200]
# Out:
#      PassengerId  Survived  Pclass  \
# 24           916         1       1
# 53           945         1       1
# 59           951         1       1
# 64           956         0       1
# 69           961         1       1
# 74           966         1       1
# 75           967         0       1
# 81           973         0       1
# 114         1006         1       1
# 142         1034         0       1
# 156         1048         1       1
# 184         1076         1       1
# 202         1094         0       1
# 218         1110         1       1
# 324         1216         1       1
# 343         1235         1       1
# 375         1267         1       1
# 407         1299         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# ...

# %%
import seaborn as sns
sns.histplot(df['Fare'],kde=True,bins=10)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(df['Age'],kde=True,bins=10)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
df['Name'].dtype
# Out:
# dtype('O')

# %%
df['Age'].mean()
# Out:
# 30.272590361445783

# %%
df['Fare'].mean()
# Out:
# 35.627188489208635

# %%
df['Fare'].corr(df['Age'])
# Out:
# 0.3379315845519922

# %%
df['Age'].corr(df['Fare'])
# Out:
# 0.3379315845519922

# %%
df['Sex'].replace(['male','female'],[1,0],inplace=True)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name  Sex   Age  \
# 0          892         0       3                  Kelly, Mr. James    1  34.5
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)    0  47.0
#
#    SibSp  Parch  Ticket    Fare Cabin Embarked
# 0      0      0  330911  7.8292   NaN        Q
# 1      1      0  363272  7.0000   NaN        S

# %%
df.drop('Embarked',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
df.drop(['Cabin','Embarked'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                              Wirz, Mr. Albert    1  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
#
#     Ticket     Fare
# 0   330911   7.8292
# 1   363272   7.0000
# 2   240276   9.6875
# 3   315154   8.6625
# 4  3101298  12.2875

# %%
df['Fare'].value_counts()
# Out:
# 7.7500      21
# 26.0000     19
# 8.0500      17
# 13.0000     17
# 7.8958      11
#             ..
# 31.6833      1
# 16.0000      1
# 53.1000      1
# 146.5208     1
# 20.2500      1
# Name: Fare, Length: 169, dtype: int64

# %%
df['Ticket'].value_counts()
# Out:
# PC 17608              5
# CA. 2343              4
# 113503                4
# SOTON/O.Q. 3101315    3
# C.A. 31029            3
#                      ..
# 244358                1
# 348125                1
# 3101295               1
# 3410                  1
# 2621                  1
# Name: Ticket, Length: 363, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 5      1
# 6      1
# Name: Parch, dtype: int64

# %%
df[(df['Sex']==1) & (df['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass                          Name  Sex   Age  \
# 0            892         0       3              Kelly, Mr. James    1  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis    1  62.0
# 3            895         0       3              Wirz, Mr. Albert    1  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin    1  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis    1  26.0
# ..           ...       ...     ...                           ...  ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton    1  50.0
# 413         1305         0       3            Spector, Mr. Woolf    1   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    1  38.5
# 416         1308         0       3           Ware, Mr. Frederick    1   NaN
# 417         1309         0       3      Peter, Master. Michael J    1   NaN
#
#      SibSp  Parch              Ticket      Fare
# ...

# %%
df[(df['Sex']==0) & (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 1                   Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# 6                               Connolly, Miss. Kate    0  30.0      0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)    0  18.0      0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)    0  23.0      1      0
# ...

# %%
df[(df['Sex']==1) & (df['Survived']==1)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare]
# Index: []

# %%
df[(df['Sex']==0) & (df['Survived']==0)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare]
# Index: []

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                              Wirz, Mr. Albert    1  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    1  14.0      0      0
# 6                          Connolly, Miss. Kate    0  30.0      0      0
# ...

# %%
df[df['Pclass']==3]['Fare'].max()
# Out:
# 69.55

# %%
df[(df['Pclass']==3) & (df['Survived']==1) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 18           910         1       3
# ..           ...       ...     ...
# 383         1275         1       3
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 412         1304         1       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# 6                            Connolly, Miss. Kate    0  30.0      0      0
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)    0  18.0      0      0
# 18                   Ilmakangas, Miss. Ida Livija    0  27.0      1      0
# ..                                            ...  ...   ...    ...    ...
# ...
