# %%
import pandas as pd
df=pd.read_csv("adaniport.csv")
df.head()
# Out:
#          Date      Symbol Series  Prev Close    Open     High    Low   Last  \
# 0  2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.0  959.0
# 1  2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.0  885.0
# 2  2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.0  887.0
# 3  2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.0  929.0
# 4  2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.0  980.0
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  962.90  984.72  27294366  2.687719e+15     NaN             9859619
# 1  893.90  941.38   4581338  4.312765e+14     NaN             1453278
# 2  884.20  888.09   5124121  4.550658e+14     NaN             1069678
# 3  921.55  929.17   4609762  4.283257e+14     NaN             1260913
# 4  969.30  965.65   2977470  2.875200e+14     NaN              816123
#
#    %Deliverble
# 0       0.3612
# 1       0.3172
# 2       0.2088
# 3       0.2735
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
df.shape
# Out:
# (3322, 15)

# %%
df['Symbol'].unique()
# Out:
# array(['MUNDRAPORT', 'ADANIPORTS'], dtype=object)

# %%
df['Volume'].unique()
# Out:
# array([27294366,  4581338,  5124121, ..., 11156977, 13851910, 12600934],
#       dtype=int64)

# %%
df['%Deliverble'].unique()
# Out:
# array([0.3612, 0.3172, 0.2088, ..., 0.1203, 0.0942, 0.2789])

# %%
df['Trades'].unique()
# Out:
# array([    nan,  19171.,  16176., ..., 130847., 153293., 132141.])

# %%
df['Turnover'].describe()
# Out:
# count    3.322000e+03
# mean     1.070144e+14
# std      2.625564e+14
# min      2.415857e+11
# 25%      1.817650e+13
# 50%      5.836041e+13
# 75%      1.158526e+14
# max      8.160988e+15
# Name: Turnover, dtype: float64

# %%
df['Open'].describe()
# Out:
# count    3322.000000
# mean      344.763019
# std       193.619992
# min       108.000000
# 25%       164.850000
# 50%       325.750000
# 75%       401.000000
# max      1310.250000
# Name: Open, dtype: float64

# %%
df['Prev Close'].describe()
# Out:
# count    3322.000000
# mean      344.114314
# std       192.936882
# min       108.000000
# 25%       164.312500
# 50%       324.700000
# 75%       400.912500
# max      1307.450000
# Name: Prev Close, dtype: float64

# %%
df['Close'].describe()
# Out:
# count    3322.000000
# mean      344.201626
# std       193.045886
# min       108.000000
# 25%       164.312500
# 50%       324.700000
# 75%       400.912500
# max      1307.450000
# Name: Close, dtype: float64

# %%
 df['Open'].describe()
# Out:
# count    3322.000000
# mean      344.763019
# std       193.619992
# min       108.000000
# 25%       164.850000
# 50%       325.750000
# 75%       401.000000
# max      1310.250000
# Name: Open, dtype: float64

# %%
df['Open'].map(type)!=float
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3317    False
# 3318    False
# 3319    False
# 3320    False
# 3321    False
# Name: Open, Length: 3322, dtype: bool

# %%
df.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume      int64
# %Deliverble           float64
# dtype: object

# %%
df['Volume'].max()
# Out:
# 97717880

# %%
df['Volume'].min()
# Out:
# 12366

# %%
df['Volume'].describe()
# Out:
# count    3.322000e+03
# mean     2.954564e+06
# std      4.104227e+06
# min      1.236600e+04
# 25%      7.493682e+05
# 50%      2.007292e+06
# 75%      3.636883e+06
# max      9.771788e+07
# Name: Volume, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.loc[3:10,:]
# Out:
#           Date      Symbol Series  Prev Close     Open    High     Low  \
# 3   2007-11-30  MUNDRAPORT     EQ      884.20   890.00   958.0   890.0
# 4   2007-12-03  MUNDRAPORT     EQ      921.55   939.75   995.0   922.0
# 5   2007-12-04  MUNDRAPORT     EQ      969.30   985.00  1056.0   976.0
# 6   2007-12-05  MUNDRAPORT     EQ     1041.45  1061.00  1099.5  1050.0
# 7   2007-12-06  MUNDRAPORT     EQ     1082.45  1089.00  1109.7  1051.0
# 8   2007-12-07  MUNDRAPORT     EQ     1081.30  1100.00  1134.0  1078.0
# 9   2007-12-10  MUNDRAPORT     EQ     1102.40  1110.00  1110.0  1061.1
# 10  2007-12-11  MUNDRAPORT     EQ     1075.40  1081.00  1089.0  1041.0
#
#        Last    Close     VWAP   Volume      Turnover  Trades  \
# 3    929.00   921.55   929.17  4609762  4.283257e+14     NaN
# 4    980.00   969.30   965.65  2977470  2.875200e+14     NaN
# 5   1049.00  1041.45  1015.39  4849250  4.923867e+14     NaN
# 6   1084.00  1082.45  1082.79  2848209  3.084010e+14     NaN
# ...

# %%
df.loc[:,['Open','Volume']]
# Out:
#         Open    Volume
# 0     770.00  27294366
# 1     984.00   4581338
# 2     909.00   5124121
# 3     890.00   4609762
# 4     939.75   2977470
# ...      ...       ...
# 3317  733.00   9390549
# 3318  735.00  20573107
# 3319  755.00  11156977
# 3320  753.20  13851910
# 3321  739.00  12600934
#
# [3322 rows x 2 columns]

# %%
df.loc[df.Open>1250]
# Out:
#           Date      Symbol Series  Prev Close     Open    High      Low  \
# 22  2007-12-31  MUNDRAPORT     EQ     1249.10  1263.35  1295.0  1261.00
# 23  2008-01-01  MUNDRAPORT     EQ     1268.80  1279.00  1319.0  1263.70
# 24  2008-01-02  MUNDRAPORT     EQ     1296.85  1310.25  1324.0  1270.00
# 25  2008-01-03  MUNDRAPORT     EQ     1307.45  1305.00  1314.7  1261.15
# 26  2008-01-04  MUNDRAPORT     EQ     1275.80  1278.80  1294.8  1233.00
#
#        Last    Close     VWAP  Volume      Turnover  Trades  \
# 22  1268.00  1268.80  1277.64  737249  9.419421e+13     NaN
# 23  1308.00  1296.85  1285.72  491348  6.317346e+13     NaN
# 24  1300.15  1307.45  1302.15  703815  9.164734e+13     NaN
# 25  1267.15  1275.80  1289.24  505058  6.511425e+13     NaN
# 26  1239.90  1240.35  1256.03  550795  6.918167e+13     NaN
#
#     Deliverable Volume  %Deliverble
# 22              316377       0.4291
# 23              172911       0.3519
# 24              221397       0.3146
# ...

# %%
df['Prev Close'].value_counts()
# Out:
# 285.65    5
# 146.05    5
# 339.55    5
# 137.95    5
# 148.30    5
#          ..
# 788.80    1
# 230.60    1
# 383.40    1
# 284.10    1
# 343.15    1
# Name: Prev Close, Length: 2678, dtype: int64

# %%
df.iloc[ :,0:3]
# Out:
#             Date      Symbol Series
# 0     2007-11-27  MUNDRAPORT     EQ
# 1     2007-11-28  MUNDRAPORT     EQ
# 2     2007-11-29  MUNDRAPORT     EQ
# 3     2007-11-30  MUNDRAPORT     EQ
# 4     2007-12-03  MUNDRAPORT     EQ
# ...          ...         ...    ...
# 3317  2021-04-26  ADANIPORTS     EQ
# 3318  2021-04-27  ADANIPORTS     EQ
# 3319  2021-04-28  ADANIPORTS     EQ
# 3320  2021-04-29  ADANIPORTS     EQ
# 3321  2021-04-30  ADANIPORTS     EQ
#
# [3322 rows x 3 columns]

# %%
sns.histplot(df['Volume'],kde=True,bins=50)
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Count'>

# %%
sns.jointplot(x='Open',y='Volume',data=df,kind='kde')

# %%
sns.pairplot(df)

# %%
sns.rugplot(df['Volume'])
# Out:
# <AxesSubplot:xlabel='Volume'>

# %%
sns.kdeplot(df['Open'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Density'>

# %%
sns.kdeplot(df['Close'])
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Density'>

# %%
sns.kdeplot(df['Low'])
# Out:
# <AxesSubplot:xlabel='Low', ylabel='Density'>

# %%
sns.kdeplot(df['Volume'])
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Density'>

# %%
sns.kdeplot(df['Last'])
# Out:
# <AxesSubplot:xlabel='Last', ylabel='Density'>

# %%
sns.kdeplot(df['%Deliverble'])
# Out:
# <AxesSubplot:xlabel='%Deliverble', ylabel='Density'>

# %%
sns.barplot(x='Date',y='Open',data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
sns.barplot(x='Open',y='Close',data=df)
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
df.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.997228  0.995592  0.996221  0.995130
# Open                  0.997228  1.000000  0.998697  0.998741  0.997855
# High                  0.995592  0.998697  1.000000  0.997991  0.999045
# Low                   0.996221  0.998741  0.997991  1.000000  0.998788
# Last                  0.995130  0.997855  0.999045  0.998788  1.000000
# Close                 0.995193  0.997934  0.999058  0.998904  0.999961
# VWAP                  0.995842  0.998748  0.999504  0.999184  0.999605
# Volume                0.055715  0.060509  0.068102  0.058525  0.066266
# Turnover              0.218236  0.225149  0.233603  0.223279  0.231077
# Trades                0.564067  0.566414  0.581243  0.555585  0.569473
# Deliverable Volume   -0.139582 -0.135827 -0.131160 -0.136498 -0.131522
# %Deliverble          -0.248207 -0.249195 -0.254316 -0.249176 -0.253037
#
# ...

# %%
df['Volume'].corr(df['Close'])
# Out:
# 0.06646379245909774

# %%
df['Volume'].corr(df['Turnover'])
# Out:
# 0.9079140360405575

# %%
df[df['Close']==df['Close'].max()]
# Out:
#           Date      Symbol Series  Prev Close     Open    High     Low  \
# 24  2008-01-02  MUNDRAPORT     EQ     1296.85  1310.25  1324.0  1270.0
#
#        Last    Close     VWAP  Volume      Turnover  Trades  \
# 24  1300.15  1307.45  1302.15  703815  9.164734e+13     NaN
#
#     Deliverable Volume  %Deliverble
# 24              221397       0.3146

# %%
df.loc[20:25,:]
# Out:
#           Date      Symbol Series  Prev Close     Open    High      Low  \
# 20  2007-12-27  MUNDRAPORT     EQ     1199.90  1215.00  1240.0  1204.00
# 21  2007-12-28  MUNDRAPORT     EQ     1211.65  1189.40  1274.0  1175.00
# 22  2007-12-31  MUNDRAPORT     EQ     1249.10  1263.35  1295.0  1261.00
# 23  2008-01-01  MUNDRAPORT     EQ     1268.80  1279.00  1319.0  1263.70
# 24  2008-01-02  MUNDRAPORT     EQ     1296.85  1310.25  1324.0  1270.00
# 25  2008-01-03  MUNDRAPORT     EQ     1307.45  1305.00  1314.7  1261.15
#
#        Last    Close     VWAP   Volume      Turnover  Trades  \
# 20  1209.00  1211.65  1222.58   977495  1.195065e+14     NaN
# 21  1270.00  1249.10  1221.31  1164138  1.421773e+14     NaN
# 22  1268.00  1268.80  1277.64   737249  9.419421e+13     NaN
# 23  1308.00  1296.85  1285.72   491348  6.317346e+13     NaN
# 24  1300.15  1307.45  1302.15   703815  9.164734e+13     NaN
# 25  1267.15  1275.80  1289.24   505058  6.511425e+13     NaN
#
# ...

# %%
df[df['%Deliverble']==df['%Deliverble'].max()]
# Out:
#            Date      Symbol Series  Prev Close   Open   High    Low   Last  \
# 355  2009-05-18  MUNDRAPORT     EQ      471.75  499.9  566.0  499.9  530.0
#
#       Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 355  523.35  545.76   12366  6.748924e+11     NaN               12116
#
#      %Deliverble
# 355       0.9798
